# %% [markdown]
# # How did total number of weekly active students change over the semester¶

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np


# load student by race
f = open('/home/jenny/remote_learning_phase1_deliverable_07202020/user_racial_groups.pkl', 'rb')
stu_race = pickle.load(f)
races = list(stu_race.keys())
print(stu_race.keys())

# Student events include submitting assignment, commenting on submission, creating discussion topic, creating discussion entries.

# load submission
submission = pd.read_csv('/home/jenny/remote_learning_phase1_deliverable_07202020/Spring 2020/submissions/submissions_000', sep='\t', header=0)
submission = submission.loc[(submission['created_at'].notnull())&(submission['created_at']>='2020-01-14')&(submission['created_at']<='2020-05-15'), ['user_id', 'assignment_id', 'created_at','submitted_at']] # no duplicate exists
submission = submission.loc[(submission['submitted_at'].notnull())&(submission['submitted_at']>='2020-01-14')&(submission['submitted_at']<='2020-05-15')]

# loading submission comments
comments = pd.read_csv('/home/jenny/remote_learning_phase1_deliverable_07202020/Spring 2020/submission_comments/submission_comments_000', sep='\t', header=0)

# loading discussions
announce = pd.read_csv('/home/jenny/remote_learning_phase1_deliverable_07202020/Spring 2020/discussion_topics/discussion_topics_000', sep='\t', header=0)
announce = announce.loc[(announce['created_at']>='2020-01-14')&(announce['created_at']<='2020-05-15')]

# loading discussion entries
discussion = pd.read_csv('/home/jenny/remote_learning_phase1_deliverable_07202020/Spring 2020/discussion_entry/discussion_entry_000', sep='\t', header=0)
discussion = discussion.loc[(discussion['created_at']>='2020-01-14')&(discussion['created_at']<='2020-05-15')]
# Out:
# dict_keys(['African American', 'Asian', 'Chicano/Latino', 'Decline to State', 'International', 'Native American/Alaskan Native', 'Pacific Islander', 'White'])

# %%
# plot all races together
african = stu_race['African American']
asian = stu_race['Asian']
chicano = stu_race['Chicano/Latino']
inter = stu_race['International']
native = stu_race['Native American/Alaskan Native']
pacific = stu_race['Pacific Islander']
white = stu_race['White']
users = [white, asian, inter, chicano, african, native, pacific]


submission_create = submission.loc[:, ['user_id', 'created_at']]
submission_create.columns = ['user_id', 'time']
submission_submit = submission.loc[:, ['user_id', 'submitted_at']]
submission_submit.columns = ['user_id', 'time']
comments = comments.loc[(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<='2020-05-15'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments = comments.loc[:, ['author_id', 'created_at']]
comments.columns = ['user_id', 'time']
announce = announce.loc[(announce['workflow_state']=='active'), ['user_id', 'created_at']]
announce.columns = ['user_id', 'time']
discussion = discussion.loc[(discussion['workflow_state']=='active'), ['user_id', 'created_at']]
discussion.columns = ['user_id', 'time']
user_time = pd.concat((submission_create, submission_submit, comments, announce, discussion), axis=0)
# transfer day to week
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

active_user_num = []
all_users = user_time['user_id'].drop_duplicates()
for i in range(len(users)):
    active_user_num.append(len(set(all_users).intersection(set(users[i]))))
    
print(active_user_num)

user_time_group = user_time.groupby('time')
user_actions_num = [[],[],[],[],[],[],[]]
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i) # week
    for j in range(len(users)):
        race_actions = group.loc[group['user_id'].isin(users[j])]
        num_users = len(race_actions['user_id'].drop_duplicates())
        user_actions_num[j].append([i, num_users/active_user_num[j]])
for i in range(len(user_actions_num)):
    user_actions_num[i] = sorted(user_actions_num[i], key=lambda x: x[0])

user_actions_num = np.array(user_actions_num)
user_actions_num = user_actions_num[:, :, 1]
date = ['01-14', '01-21', '01-28', '02-04', '02-11', '02-18', '02-25', '03-03', '03-10', '03-17', '03-24', '03-31', '04-07', '04-14', '04-21', '04-28', '05-05', '05-12']
plt.plot(date, user_actions_num[0], scalex=True, scaley=True, data=None, marker='o', label='White')
plt.plot(date, user_actions_num[1], scalex=True, scaley=True, data=None, marker='x', label='Asian')
plt.plot(date, user_actions_num[2], scalex=True, scaley=True, data=None, marker='+', label='International')
plt.plot(date, user_actions_num[3], scalex=True, scaley=True, data=None, marker='', label='White')

plt.legend()

plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Weekly active students proportion in Spring 2020', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message_size_bytes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-96a99fe07347> in <module>
# ...

# %%
print(np.array(user_actions_num)[:,:,1])
# Out:
# [[0.0174144  0.04146989 0.04250295 0.0464876  0.04338843 0.04530697
#   0.04456907 0.04634002 0.05327627 0.04899646 0.03645218 0.05386659
#   0.05091499 0.05239079 0.04929162 0.05106257 0.04220779 0.04545455]
#  [0.28955224 0.65820896 0.72238806 0.76268657 0.7358209  0.75373134
#   0.74477612 0.78656716 0.85223881 0.80149254 0.55223881 0.86865672
#   0.86865672 0.83283582 0.83432836 0.83134328 0.66268657 0.69104478]
#  [0.01867929 0.0463036  0.05077611 0.05156538 0.04972376 0.05051302
#   0.04840831 0.05156538 0.05630097 0.05261773 0.03604315 0.05472244
#   0.05551171 0.053407   0.05419626 0.05261773 0.04577743 0.04130492]
#  [0.31538462 0.70769231 0.72692308 0.73461538 0.72307692 0.73461538
#   0.70384615 0.76923077 0.85769231 0.76153846 0.54230769 0.81538462
#   0.83846154 0.78846154 0.78461538 0.81923077 0.64615385 0.72307692]
#  [0.37288136 0.74576271 0.88135593 0.84745763 0.79661017 0.76271186
#   0.84745763 0.77966102 0.89830508 0.81355932 0.55932203 0.81355932
# ...

# %%
race_students = stu_race[races[0]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, comments announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[0])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[1]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[1])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[2]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[2])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[3]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[3])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[4]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[4])+' students over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[5]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[5])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[6]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[6])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()

# %%
race_students = stu_race[races[7]]
num_students = len(race_students)

submission1 = submission.loc[submission['user_id'].isin(race_students)]
create_time = submission1.loc[:, ['user_id', 'created_at']]
submit_time = submission1.loc[:, ['user_id', 'submitted_at']]
create_time.columns = ['user_id', 'time']
submit_time.columns = ['user_id', 'time']

comments1 = comments.loc[(comments['author_id'].isin(race_students))&(comments['message_size_bytes']>0)&(comments['created_at']>='2020-01-14')&(comments['created_at']<'2020-05-25'), ['author_id', 'submission_id', 'assignment_id', 'created_at', 'message_size_bytes']]
comments_time = comments1.loc[:, ['author_id', 'created_at']]
comments_time.columns = ['user_id', 'time']

announce1 = announce.loc[(announce['workflow_state']=='active')&(announce['user_id'].isin(race_students))]
announce_time = announce1.loc[:, ['user_id', 'created_at']]
announce_time.columns = ['user_id', 'time']

discussion1 = discussion.loc[(discussion['workflow_state']=='active')&(discussion['user_id'].isin(race_students))]
discussion_time = discussion1.loc[:, ['user_id', 'created_at']]
discussion_time.columns = ['user_id', 'time']
                          
user_time = pd.concat((create_time, submit_time, announce_time, discussion_time), axis=0)
user_time['time'] = pd.to_datetime(user_time['time'], format='%Y-%m-%d %H:%M:%S.%f')
user_time['time'] = user_time['time'].apply(lambda x: x.date())
user_time['time'] = user_time['time'].apply(lambda x: x.isocalendar()[1])
min_week = min(user_time['time'].tolist())
user_time['time'] = user_time['time'] - min_week+1

user_time_group = user_time.groupby('time')
li = []
for i in user_time_group.groups.keys():
    group = user_time_group.get_group(i)
    num_users = len(group['user_id'].drop_duplicates())
    li.append([i, num_users/num_students])
li = sorted(li, key=lambda x: x[0])
li = np.array(li)
plt.bar(li[:, 0], li[:, 1], 0.35)
#plt.ylim(bottom=0)
plt.xticks(li[:, 0], fontsize=70)
plt.yticks(fontsize=70)
plt.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 90
fig_size[1] = 50
plt.rcParams["figure.figsize"] = fig_size
plt.title('Amount of daily students events of '+str(races[7])+' over the semester', fontsize=100)
plt.xlabel('week', fontsize=70)
plt.ylabel('proportion of active students(%)', fontsize=70)
plt.show()
